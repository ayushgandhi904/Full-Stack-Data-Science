# %% [markdown]
# ### function

# %%
#to start with function start with def

def test():
  pass

# %%
def test1():
  print("This is my first function is python")

# %%
test1()
# Out:
# This is my first function is python

# %%
a = test1()
# Out:
# This is my first function is python

# %%
a

# %%
def test2():
  return(print("This is test"))

# %%
test2()
# Out:
# This is test

# %%
b = test2()
# Out:
# This is test

# %%
b

# %%
def test3():
  return("This should return")

# %%
test3() + "Hello"
# Out:
# 'This should returnHello'

# %%
def test6():
  return 8, "Hello", [2, "8+i", 2.9, (True, 9j+ 2)]

# %%
test6()
# Out:
# (8, 'Hello', [2, '8+i', 2.9, (True, (2+9j))])

# %%
#return type for different data types is tuple

# %%
type(test6())
# Out:
# tuple

# %%
test6()[2][3][1]
# Out:
# (2+9j)

# %%
a, b, c = test6()

# %%
a
# Out:
# 8

# %%
c
# Out:
# [2, '8+i', 2.9, (True, (2+9j))]

# %%
def test8():
  a = 85*12 + 5
  return a

# %%
test8()
# Out:
# 1025

# %%
l = [1, 5, 9, 58, 29, 19]
a = 0

for i in l:
  a = a+i
print(a)
# Out:
# 121

# %%
def test9():
  l = [1, 5, 9, 58, 29, 19]
  a = 0

  for i in l:
    a = a+i
  return a

# %%
test9()
# Out:
# 121

# %%
def test9():
  l = [1, 5, 9, 58, 29, 19, "hello"]
  a = 0
  for i in l:
    if type(i) == int:
      a = a+i
  return a

# %%
test9()
# Out:
# 121

# %%
def test10(l):
  a = 0
  for i in l:
    if type(i) == int:
      a = a+i
  return a

# %%
l2 = [1, 5, 5, 9+9j]

# %%
test10(l2)
# Out:
# 11

# %%
def summ(a, b):
  return a+b

# %%
summ(1, 5)
# Out:
# 6

# %%
summ("Hello", " Ayush")
# Out:
# 'Hello Ayush'

# %%
a = ["h", 2, 59, 67, "come", "ohyes"]

# %%
def string(s):
  b = []
  for i in s:
    if type(i) == str:
      b.append(i)
  return b

# %%
string(a)
# Out:
# ['h', 'come', 'ohyes']

# %%
def string(s):
  """this will sepatre string list argument from the list"""
  b = []
  for i in s:
    if type(i) == str:
      b.append(i)
  return b

# %%
string()
