# %% [markdown]
# #### Q-1 What is indentation error? Why indentation is important? Give one simple example?

# %%
# 1. indentation error is error which  happen when any line or word is not proper indented eg. :not given proper space.
# 2. It is important as it gives user the sense of continuity to previous line of code, which helps to understand the user which code follows which code above
# 3. Eg:-

# %%
#wrong indentation
a = "hello"
b = 5

if a == b:
print("you are going correct way")
else:
print("Please stop")
# Out:
#   File "<ipython-input-2-ff1830f05d7d>", line 5
#     print("you are going correct way")
#         ^
# IndentationError: expected an indented block

# %%
#here if proper space is not given after if & else statment, it will give proper reason

a = "hello"
b = 5

if a == b:
  print("you are going correct way") #here
else:
  print("Please stop") #here
# Out:
# Please stop

# %% [markdown]
# ### Q-2 Correct the following code and write the comment where you made the correction?

# %%
class_started = bool(int(input("Hey friend, is class started?: [0-False/1-True]"))) #added int as it would earlier consider string and take True all the time

if class_started: 
   print("Since class started...")
   print("Lets concentrate")
else:
   print("Since class is not started...")
   print("let's revise")
# Out:
# Hey friend, is class started?: [0-False/1-True]0
# Since class is not started...
# let's revise

# %% [markdown]
# ### Q-3 Use if else condition to verify that dataype of input() method in python is always string.

# %%
a = input("Enter any integer number:")
b = input("Enter any float number:")
c = input("Enter bolean:")

if type(a) == int:
  print(f"Datatype of a is {type(a)}")
else:
  print(f"Datatype of a is {type(a)}")

if type(b) == float:
  print(f"Datatype of b is {type(a)}")
else:
  print(f"Datatype of b is {type(b)}")

if type(c) == bool:
  print(f"Datatype is of c {type(c)}")
else:
  print(f"Datatype is of c {type(c)}")
# Out:
# Enter any integer number:8
# Enter any float number:7.2
# Enter bolean:True
# Datatype of a is <class 'str'>
# Datatype of b is <class 'str'>
# Datatype is of c <class 'str'>

# %%
#from above example it can be noted datatype of input is always string

# %% [markdown]
# ### Q-4 Take 3 variables and assign integer values to them. Find the largest variable, by only using the if and else conditions

# %%
a = 12
b = 33
c = 23

if a>b and a>c:
  print(f"{a} is the largest value of all given")
if b>a and b>c:
  print(f"{b} is the largest value of all given")
else:
  print(f"{c} is the largest value of all given")
# Out:
# 33 is the largest value of all given

# %% [markdown]
# ### Q-5 What would be the solution?
#
# True
#
# False

# %%
a = 6
b = 10
print( not ( not a == 10 or not b == 10) )

""" 
=[not[not[FALSE] or not[TRUE]]]
=[not[TRUE or FALSE]]
=[not[TRUE]]
=[FALSE]
"""

#it should be print false
# Out:
# False
# ' \n=[not[not[FALSE] or not[TRUE]]]\n=[not[TRUE or FALSE]]\n=[not[TRUE]]\n=[FALSE]\n'

# %% [markdown]
# ### Q-6 Find the answer as well as find out the reason behind the result?

# %% [markdown]
# - case 1

# %%
  A = 5.0
  B = 10/2
  print(A is B)

  #it will come False though A & B are having equal value i.e. 5.0 as B has come by float after dividing 10/2 as theri memmory address will be diffrent, i.e their ID
# Out:
# False

# %%
print(id(A))
print(id(B))
# Out:
# 139836671173840
# 139836671174960

# %% [markdown]
# - case 2

# %%
  A = 5.0
  B = int(10/2)
  print(A is B)

  #it will also come False because of B is will be integer & id will also be different
# Out:
# False

# %% [markdown]
# - case 3

# %%
  A = 5.0
  B = float(10/2)
  print(A is B)

  #it will also be false as mentioned above, their id address will be different
# Out:
# False

# %%
print(id(A))
print(id(B))
# Out:
# 139836671058320
# 139836671173840

# %% [markdown]
# ### Q - 7 Write a program that asks the user to enter a number. You should print out a message to the user, either “That number is divisible by either 3 or 5”, or “That number is not divisible by either 3 or 5”. Be sure to consider the data type of the input you are taking in from the user. Use a single if/else block to solve this problem.

# %%
number = int(input("Enter the number:"))

if number%3 == 0 or number%5 == 0:
  print("Number is divisible by either 3 or 5")
else:
  print("Number is not divisible by either 3 or 5")
# Out:
# Enter the number:78
# Number is divisible by either 3 or 5

# %% [markdown]
# ### Q-8 Take user input for length and width. Then calculate the area of rectangle. Also print as per length and width whether its a square of rectangle.

# %%
length = int(input("Enter the length: "))
breath = int(input("Enter the breath: "))

area = length*breath
print(f"Area of rectangle is {area} units")

if length == breath:
  print("It is square")
else:
  print("It is rectangle")
# Out:
# Enter the length: 12
# Enter the breath: 13
# Area of rectangle is 156 units
# It is rectangle

# %% [markdown]
# ### Q-9 Take two variable radius_1 and radius_2 and calculate the area of circle_1 and circle_2. Also print which circle has large area. If area is equal then print area is equal.

# %%
radius_1 = int(input("Enter the radius 1: "))
radius_2 = int(input("Enter the radius 2: "))

Area_1 = 3.14*((radius_1)**2)
Area_2 = 3.14*((radius_2)**2)

if Area_1 > Area_2:
  print("Circle 1 has larger area")
if Area_1 == Area_2:
  print("Both circle has equal area")
else:
  print("Cicrle 2 has larger area")
# Out:
# Enter the radius 1: 45
# Enter the radius 2: 45
# Both circle has equal area

# %% [markdown]
# ### Q-10 Check whether a year is leap year or not. Use nested if...else to solve this problem. A leap year is exactly divisible by 4 except for century years (years ending with 00). The century year is a leap year only if it is perfectly divisible by 400.

# %%
year = int(input("Enter the year you want to check: "))

if (year%4 == 0 or year%100 != 0) and year%400 == 0:
  print("It is leap year")
else:
  print("It is not leap year")
# Out:
# Enter the year you want to check: 3000
# It is not leap year

# %%
year = int(input("Enter the year you want to check: "))

if (year%4 == 0 or year%100 != 0) and year%400 == 0:
  print("It is leap year")
else:
  print("It is not leap year")
# Out:
# Enter the year you want to check: 8000
# It is leap year
