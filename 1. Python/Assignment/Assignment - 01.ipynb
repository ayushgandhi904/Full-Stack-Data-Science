# %% [markdown]
# ### Q-1 Finding out the types of error we have encountered with example

# %%
# 1)Name error - It comes when any name is not defined 
#it happens when we use when we use wrong case or the word which we have not defined 

Print("Hey Ayush") #eg : "print" is defined not the "Print"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c47460026ae6> in <module>
#       2 #it happens when we use when we use wrong case or the word which we have not defined
#       3
# ----> 4 Print("Hey Ayush") #eg
#
# NameError: name 'Print' is not defined

# %%
# 2) Syntax error - It comes when proper sytax or paranthesis is not provided, variable name defining start with number, symbol etc or it is not given proper space etc. 

print "Hello" #eg - parantheses is missing ()
# Out:
#   File "<ipython-input-2-f223c9fa49c6>", line 3
#     print "Hello"
#                 ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello")?

# %%
 # 3) Type error - It occurs during addition, subraction or during mathematcial operation when they both aren't the same type & operation can't perform on them. 

"Hey buddy" - 100 #subrtaction operation is perform between string & integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-bc9d6acfe7c5> in <module>
#       1 #Type error - It occurs during addition, subraction or during mathematcial operation when they both aren't the same type of value & operation is perform on them.
#       2
# ----> 3 "Hey buddy" - 100
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
#4 Value error - This happens when particular value is invalid or not able to covert into it's type

A = "Ayush"
A = int(A)
print(type(A)) #Eg :- integer for Ayush can't be define for value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6dc0223384c3> in <module>
#       2
#       3 A = "Ayush"
# ----> 4 A = int(A)
#       5 print(type(A))
#
# ValueError: invalid literal for int() with base 10: 'Ayush'

# %% [markdown]
# ### Q-2 Take input A&B & print their sum, mul, div, square of the nos.

# %%
a = float(input("Enter the number a: "))
b = float(input("Enter the number b: "))

print(f"Sum of the numbers is {a+b}")
print(f"Multiplication of numbers is {a*b}")
print(f"Divison of no a/b is {a/b}")
print(f"The square of both numbers is {a**2} & {b**2} respctively")
# Out:
# Enter the number a: 5
# Enter the number b: 2
# Sum of the numbers is 7.0
# Multiplication of numbers is 10.0
# Divison of no a/b is 2.5
# The square of both numbers is 25.0 & 4.0 respctively

# %% [markdown]
# ### Q-3 How many reservere keywords are there & why we should not use variable ?

# %%
#there are about 27 reserve keywords in python like print, if , elif, else etc. 
#it can be use but it is not favourable as they are self define some function and if values are assign to them thy will not be able to used for any statment

# %% [markdown]
# ### Q-4 Create email ids with user input.

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
print(f"{last_name}.{first_name}@gmail.com")
# Out:
# Enter your first name: ayush
# Enter your last name: gandhi
# gandhi.ayush@gmail.com

# %% [markdown]
# ### Q-5 Print the  lines

# %%
print("""
Hi I'm Sunny
My address is 22\3
I earn 20$ daily
""")
# Out:
# Hi I'm Sunny
# My address is 22
# I earn 20$ daily

# %% [markdown]
# ### Q-6 Input their ids for college form & fill their email

# %%
name = input("Enter your name: ")
addres = input("Enter your city address: ")
DOB = int(input("Enter your birthe date: "))

print(f"Your email id will be {name}.{DOB}@ineuron.com")
# Out:
# Enter your name: ayush
# Enter your city address: HYD
# Enter your birthe date: 4
# Your email id will be ayush.4@ineuron.com

# %% [markdown]
# ### Q-7 Convert the following

# %%
A = "22.4" #---->str to intger will not be possible directly so we first have to convert to float to get into integer 

print(int(float(A)))
# Out:
# 22

# %%
B = "22" 
print(complex(B))
# Out:
# (22+0j)
