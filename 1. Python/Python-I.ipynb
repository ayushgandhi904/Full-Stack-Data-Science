# %%
print("Hello Neuron")
# Out:
# Hello Neuron

# %%
print("Hello Good evening")
# Out:
# Hello Good evening

# %%
"Good morning"
# Out:
# 'Good morning'

# %%
print("""
You can print any line of code with 3 colos""")
# Out:
# You can print any line of code with 3 colos

# %%
#to avoid next quotes use """"___""""

print("""Hello "Ayush", How are you ?""")
# Out:
# Hello "Ayush", How are you ?

# %%
#variable in python

# %%
2 + 3 #addition
# Out:
# 5

# %%
8*7 #multiplication
# Out:
# 56

# %%
9 - 1 #subtraction
# Out:
# 8

# %%
3/2 #division
# Out:
# 1.5

# %%
882 % 9 #reminder
# Out:
# 0

# %% [markdown]
# ### Variable in Python

# %%
#variable name should start with alphabet
#should not contain some special variable
#can't start with number
#recommend to use with small variable

# %%
ten = 10
ten_number = 10
tenNumber = 10

# %%
10ten = 10
# Out:
#   File "<ipython-input-17-c508e1cc1cd5>", line 1
#     10ten = 10
#         ^
# SyntaxError: invalid syntax

# %%
__num = 10 #hidden variable

# %%
Ten = 10

# %% [markdown]
# ## Fundamental data types

# %% [markdown]
# #### Integers - Nos without decimal

# %%
a = 7
type(a)
# Out:
# int

# %% [markdown]
# #### Floats - no containing decimal

# %%
pi = 22/7
type(pi)
# Out:
# float

# %% [markdown]
# #### Complex - no with imaginary & real value

# %%
x = 2 + 3j
type(x)
# Out:
# complex

# %%
## to get real & imaginary value

x.real
# Out:
# 2.0

# %%
x.imag
# Out:
# 3.0

# %% [markdown]
# ### Dynamic Typing

# %%
#we don't need to redefine anything,it automatically defines it

a = 22
print(type(a))
a = 22.3
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>

# %%
A = "Ayush"
print(type(A))
# Out:
# <class 'str'>

# %% [markdown]
# ## Strong Typing

# %%
#need same data type to cocanate for string
"22" + "_"
# Out:
# '22_'

# %%
#to change variable according to data

#1 add + for string

lang = "Python"
print("Hi welcome " + lang + " class" )
# Out:
# Hi welcome Python class

# %%
#2 f after print
lang = "Java"
lan = "Python"
print(f"hey welcome {lang}") #use approach
# Out:
# hey welcome Java

# %%
#3 .format for the string to filled
print("Hey girl, my name is {} & {}".format(lang, lan))
# Out:
# Hey girl, my name is Java & Python

# %%
a = 22
b = 3j 
c = a + b
print (f"a:{a} + b:{b} is c:{c}")
# Out:
# a:22 + b:3j is c:(22+3j)

# %% [markdown]
# #### Boolean - True or False (0 or 1)

# %%
h = True
i = False
print(type(h))
# Out:
# <class 'bool'>

# %%
start = 15
you_came = 18
start < you_came
# Out:
# True

# %%
raining = True
print(f"Is it is {raining}")
# Out:
# Is it is True
